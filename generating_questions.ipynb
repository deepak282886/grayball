# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/grayball/
# Out:
# /content/drive/MyDrive/grayball

# %%
import pandas as pd
import sqlite3

cols = ['match_id', 'team', 'innings_number','over_number', 'powerplay_type', 'powerplay_number', 'ball_number', 'batter', 'batter_number', 'non_striker_number',
        'bowler', 'bowler_number','non_striker', 'runs_batter', 'extras_total', 'target_overs', 'target_runs', 'wickets_player_out',
        'wickets_kind', 'fielder1_wicket', 'fielder2_wicket', 'fielder3_wicket', 'legbyes_extras','wides_extras', 'byes_extras',
        'noballs_extras' ,'penalty_extras']
cols1 = ['match_id_2', 'balls_per_over', 'city', 'dates', 'event_name', 'event_match_number', 'gender', 'match_type',
        'match_type_number', 'official_match_referees', 'official_reserve_umpires', 'official_tv_umpires', 'official_umpires',
        'outcome_winner', 'outcome_wickets', 'outcome_runs', 'overs', 'player_of_match', 'players_team1', 'players_team2', 'season',
        'team_type', 'teams', 'toss_decision', 'toss_winner', 'venue', 'team1', 'team2']

cols_full = ['team', 'innings_number','over_number', 'powerplay_type', 'powerplay_number', 'ball_number', 'batter', 'batter_number', 'non_striker_number',
        'bowler', 'bowler_number','non_striker', 'runs_batter', 'extras_total', 'target_overs', 'target_runs', 'wickets_player_out',
        'wickets_kind', 'fielder1_wicket', 'fielder2_wicket', 'fielder3_wicket', 'legbyes_extras','wides_extras', 'byes_extras',
        'noballs_extras' ,'penalty_extras','balls_per_over', 'city', 'dates', 'event_name', 'event_match_number', 'gender', 'match_type',
        'match_type_number', 'official_match_referees', 'official_reserve_umpires', 'official_tv_umpires', 'official_umpires',
        'outcome_winner', 'outcome_wickets', 'outcome_runs', 'overs', 'player_of_match', 'players_team1', 'players_team2', 'season',
        'team_type', 'teams', 'toss_decision', 'toss_winner', 'venue', 'team1', 'team2']

conn = sqlite3.connect("cricket.db")
cursor = conn.cursor()

# %%
tq = pd.DataFrame()

for cl in cols:
  if cl == "match_id":
    continue
  query_word = f"b.{cl}"
  query = f"""
      SELECT DISTINCT {query_word}
      FROM ball_by_ball_data b
      LEFT JOIN match_info m ON b.match_id = m.match_id;"""

  all_df = pd.read_sql_query(query, conn)
  all_df.columns = [f"{cl}"]
  tq = pd.concat([tq, all_df], ignore_index=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb8b998c93a4> in <cell line: 1>()
# ----> 1 tq = pd.DataFrame()
#       2
#       3 for cl in cols:
#       4   if cl == "match_id":
#       5     continue
#
# NameError: name 'pd' is not defined

# %%
tq1 = pd.DataFrame()
for cl in cols1[:]:
  if cl == "match_id_2":
    continue
  query_word = f"m.{cl}"
  query = f"""
      SELECT DISTINCT {query_word}
      FROM ball_by_ball_data b
      LEFT JOIN match_info m ON b.match_id = m.match_id;"""

  all_df = pd.read_sql_query(query, conn)
  all_df.columns = [f"{cl}"]
  tq1 = pd.concat([tq1, all_df], ignore_index=True, axis=1)

# %%
tq_full = pd.concat([tq, tq1], ignore_index=True, axis=1)

# %%
tq_full.columns = cols_full

# %%
tq_full.head()
# Out:
#            team  innings_number  over_number powerplay_type powerplay_number  \
# 0  South Africa             1.0          0.0             NA     no_powerplay
# 1     Australia             2.0          1.0      mandatory                1
# 2      Pakistan             3.0          2.0        batting                2
# 3     Sri Lanka             4.0          3.0       fielding                3
# 4   New Zealand             5.0          4.0            NaN              NaN
#
#    ball_number        batter  batter_number  non_striker_number        bowler  \
# 0          1.0       SC Cook            1.0                 2.0      MA Starc
# 1          2.0       HM Amla            3.0                 3.0  JR Hazlewood
# 2          3.0       D Elgar            2.0                 4.0     PM Siddle
# 3          4.0     JP Duminy            4.0                 5.0      MR Marsh
# 4          5.0  F du Plessis            5.0                 6.0       NM Lyon
#
# ...

# %%
cols_full = ['team', 'innings_number','over_number', 'powerplay_type', 'powerplay_number', 'ball_number', 'batter', 'batter_number', 'non_striker_number',
        'bowler', 'bowler_number','non_striker', 'runs_batter', 'extras_total', 'target_overs', 'target_runs', 'wickets_player_out',
        'wickets_kind', 'fielder1_wicket', 'fielder2_wicket', 'fielder3_wicket', 'legbyes_extras','wides_extras', 'byes_extras',
        'noballs_extras' ,'penalty_extras','balls_per_over', 'city', 'dates', 'event_name', 'event_match_number', 'gender', 'match_type',
        'match_type_number', 'official_match_referees', 'official_reserve_umpires', 'official_tv_umpires', 'official_umpires',
        'outcome_winner', 'outcome_wickets', 'outcome_runs', 'overs', 'player_of_match', 'players_team1', 'players_team2', 'season',
        'team_type', 'teams', 'toss_decision', 'toss_winner', 'venue', 'team1', 'team2']

# %% [markdown]
# ### Player

# %%
player_batting_performance_questions = [
    "What are the career batting statistics of {player}?",
    "Tell me about {player}'s total runs scored in {format}.",
    "How many centuries has {player} scored in {format} matches?",
    "Give me the details of {player}'s highest {format} score.",
    "What is the strike rate of {player} in {format} matches?",
    "Show me the number of fours hit by {player} in the last {tournament} season.",
    "How many sixes did {player} hit in his last {format} match?",
    "Tell me the average runs scored by {player} in {format} cricket.",
    "What is the highest individual score of {player} in {format}?",
    "Give me the career statistics of {player} in {format}.",
    "What is the most recent century scored by {player} in {format}?",
    "How many fifties has {player} scored in {format}?",
    "Tell me about the centuries scored by {player} in {format} matches.",
    "What is the highest partnership between {player} and {player} in {format}?",
    "Show me the batting statistics of {player} in the {tournament}.",
    "What is the strike rate of {player} in {format} leagues?",
    "How many runs did {player} score in the last {tournament}?",
    "Tell me about the centuries scored by {player} in {tournament}.",
    "What is the batting average of {player} in {format}?",
    "How many boundaries did {player} hit in the last {tournament}?",
    "Give me the details of {player}'s highest {format} score against {team}.",
    "What is the highest partnership between {player} and {player} in {format} cricket?",
    "Show me the number of sixes hit by {player} in {format}.",
    "How many centuries has {player} scored in {format}?",
    "Tell me about the strike rate of {player} in {format} matches.",
    "What is the average runs scored by {player} in {format}?",
    "Give me the career batting statistics of {player} in {format} cricket.",
    "How many fifties has {player} scored in {format}?",
    "Show me the highest individual score of {player} in {format}.",
    "What is the most recent century scored by {player} in {format}?",
    "Tell me about the runs scored by {player} in his last {tournament} match.",
    "What is the batting average of {player} in {format}?",
    "Give me the details of {player}'s highest {format} score against {team}.",
    "How many boundaries did {player} hit in the last {tournament}?",
    "Show me the number of sixes hit by {player} in {format}.",
    "How many centuries has {player} scored in {format}?",
    "Tell me about the strike rate of {player} in {format}.",
    "What is the highest partnership between {player} and {player} in {format}?",
    "Give me the career batting statistics of {player} in {format} cricket.",
    "How many runs did {player} score in the last {tournament}?",
    "Show me the batting statistics of {player} in the {tournament}.",
    "What is the highest individual score of {player} in {format}?",
    "Tell me about the centuries scored by {player} in {tournament} matches.",
    "What is the average runs scored by {player} in {format}?",
    "Give me the details of {player}'s highest {format} score in the {tournament}.",
    "How many fifties has {player} scored in {format}?",
    "Show me the highest partnership between {player} and {player} in {format}Is.",
    "What is the strike rate of {player} in {format}?",
    "Tell me about the runs scored by {player} in his last {format} match.",
    "How many boundaries did {player} hit in the last {tournament} season?",
    "Give me the number of sixes hit by {player} in {format}.",
    "Show me the career statistics of {player} in {format}.",
    "What is the most recent century scored by {player} in {format} matches?",
    "Tell me about the centuries scored by {player} in {format}.",
    "What is the highest partnership between {player} and {player} in {format}?",
    "Give me the batting statistics of {player} in {tournament} matches.",
    "How many centuries has {player} scored in {format} cricket?",
    "Show me the highest individual score of {player} in {format}.",
    "What is the average runs scored by {player} in {format}?",
    "Tell me about the strike rate of {player} in {format}.",
    "Give me the details of {player}'s highest {format} score against {team}.",
    "How many fifties has {player} scored in {format}?",
    "Show me the highest partnership between {player} and {player} in {format}.",
    "What is the runs scored by {player} in his last {format} match?",
    "Tell me about the centuries scored by {player} in {format}.",
    "What is the most recent century scored by {player} in {tournament} matches?",
    "Give me the career batting statistics of {player} in {format}.",
    "How many boundaries did {player} hit in the last {tournament}?",
    "Show me the number of sixes hit by {player} in {format}.",
    "What is the batting average of {player} in {format}?",
    "Tell me about the strike rate of {player} in {format}.",
    "Give me the highest individual score of {player} in {tournament} matches.",
    "How many centuries has {player} scored in {format}?",
    "Show me the batting statistics of {player} in {format} matches.",
    "What is the highest partnership between {player} and {player} in {format} cricket?",
    "Tell me about the runs scored by {player} in his last {format} match.",
    "What is the most recent century scored by {player} in {format} matches?",
    "Give me the details of {player}'s highest {format} score against {team}.",
    "How many fifties has {player} scored in {tournament} matches?",
    "Show me the highest partnership between {player} and {player} in {format}.",
    "What is the strike rate of {player} in {format} matches?",
    "Tell me about the centuries scored by {player} in {tournament} matches.",
    "What is the average runs scored by {player} in {format} cricket?",
    "Give me the career batting statistics of {player} in {format}.",
    "How many boundaries did {player} hit in the last {tournament}?",
    "Show me the number of sixes hit by {player} in {format}.",
    "Tell me about the runs scored by {player} in the last {tournament}",
    "What is the highest individual score of {player} in {format} leagues?",
    "Give me the strike rate of {player} in {format}.",
    "How many centuries has {player} scored in {format} matches?",
    "Show me the batting statistics of {player} in {format} matches.",
    "What is the most recent century scored by {player} in {format}?",
    "Tell me about the highest partnership between {player} and {player} in {tournament} matches."
]

# %%
player_bowling_performance_questions = [
    "What are the career bowling statistics of {player}?",
    "Tell me about {player}'s total wickets in {format} matches.",
    "How many 5-wicket hauls has {player} taken in {format}?",
    "Give me the details of {player}'s best {format} bowling figures.",
    "What is the economy rate of {player} in {format}?",
    "Show me the number of maidens bowled by {player} in his last {format} match.",
    "How many wickets did {player} take in the last {tournament}?",
    "Tell me the average runs conceded by {player} in {format}.",
    "What is the best bowling figures of {player} in {format}?",
    "Give me the career statistics of {player} in {format} cricket.",
    "What is the most recent 5-wicket haul by {player} in {format}?",
    "How many 4-wicket hauls has {player} taken in {format} matches?",
    "Tell me about the wickets taken by {player} in his last {tournament}.",
    "What is the economy rate of {player} in {format}?",
    "Show me the number of maidens bowled by {player} in {format}.",
    "How many wickets did {player} take in the last {tournament}?",
    "Give me the details of {player}'s best {format} bowling figures against {team}.",
    "What is the average runs conceded by {player} in {format}?",
    "Tell me the best bowling figures of {player} in {format} matches.",
    "Show me the wickets taken by {player} in the last {tournament} season.",
    "What is the economy rate of {player} in his last {format} match?",
    "Give me the career statistics of {player} in {format}.",
    "Tell me about the best {format} bowling figures of {player} against {team}.",
    "What is the most recent 4-wicket haul by {player} in {format}?",
    "How many maidens has {player} bowled in {format}?",
    "Show me the number of wickets taken by {player} in his last {format} match.",
    "What is the average runs conceded by {player} in {tournament} matches?",
    "Tell me the best bowling figures of {player} in {format}.",
    "How many 5-wicket hauls has {player} taken in {format} matches?",
    "Give me the wickets taken by {player} in the last {format} series against {team}.",
    "What is the economy rate of {player} in his last {tournament} season?",
    "Show me the career statistics of {player} in {format}.",
    "Tell me about the best {format} bowling figures of {player} against {team}.",
    "What is the most recent 5-wicket haul by {player} in {format} matches?",
    "How many 4-wicket hauls has {player} taken in {format}?",
    "Give me the number of wickets taken by {player} in his last {format} match.",
    "What is the average runs conceded by {player} in {format} matches?",
    "Show me the best bowling figures of {player} in {format} against {team}.",
    "How many maidens has {player} bowled in his last {format} match?",
    "Tell me about the wickets taken by {player} in his last {format} match.",
    "What is the economy rate of {player} in {format}?",
    "Give me the details of {player}'s best {format}I bowling figures against {team}.",
    "Show me the number of 5-wicket hauls taken by {player} in {format} matches.",
    "What is the most recent 4-wicket haul by {player} in {format}?",
    "Tell me the career statistics of {player} in {format} matches.",
    "How many wickets did {player} take in the last {tournament}?",
    "Give me the best {format} bowling figures of {player} against {team}.",
    "What is the average runs conceded by {player} in his last {tournament} match?",
    "Show me the best bowling figures of {player} in {format} matches against {team}.",
    "Tell me about the wickets taken by {player} in his last {tournament} match.",
    "How many 5-wicket hauls has {player} taken in {format}?",
    "Give me the details of {player}'s best {format} bowling figures against {team}.",
    "What is the economy rate of {player} in {format} matches?",
    "Show me the number of maidens bowled by {player} in his last {format} match.",
    "Tell me the best {format} bowling figures of {player} against {team}.",
    "What is the most recent 4-wicket haul by {player} in {tournament} matches?",
    "How many 5-wicket hauls has {player} taken in his last {format} match?",
    "Give me the career statistics of {player} in {format} matches against {team}.",
    "What is the average runs conceded by {player} in his last {format}I match?",
    "Tell me about the wickets taken by {player} in his last {tournament} against {team}.",
    "How many maidens has {player} bowled in {format}?",
    "Show me the best {format} bowling figures of {player} against {team}.",
    "What is the economy rate of {player} in {format} matches?",
    "Give me the details of {player}'s best {format} bowling figures against {team}.",
    "Tell me the most recent 5-wicket haul by {player} in {format} matches.",
    "How many 4-wicket hauls has {player} taken in his last {format} match against {team}?",
    "Show me the number of wickets taken by {player} in his last {format} match.",
    "What is the best bowling figures of {player} in {format} against {team}.",
    "Tell me the career statistics of {player} in {format}.",
    "How many wickets did {player} take in the last {format} series?",
    "Give me the economy rate of {player} in his last {format} match.",
    "What is the average runs conceded by {player} in his last {format} match against {team}.",
    "Show me the best {format} bowling figures of {player} against {team}.",
    "Tell me about the wickets taken by {player} in his last {format} match against {team}.",
    "How many 5-wicket hauls has {player} taken in {format}?",
    "Give me the details of {player}'s best {format} bowling figures against {team}.",
    "What is the economy rate of {player} in his last {format} match against {team}."
]

# %%
player_match_context_questions = [
    "Tell me about the result of the {team} vs. {team} match in the {tournament}.",
    "What was the final score in the {team} vs. {team} {format} match at {venue} in 2021?",
    "Who won the {format} International series between {team} and {team} in 2022?",
    "Give me the details of the {tournament} final between {team} and {team}.",
    "What is the highest team score in a {format} match at {venue}?",
    "Show me the most recent {format} match between {team} and {team} and its result.",
    "Tell me about the top run-scorer in the last season of the {tournament}.",
    "What was the outcome of the {tournament} between {team} and {team} in 2019?",
    "Give me information about the {tournament} final between {team} and {team}.",
    "Who was the Man of the Match in the last {team} vs. {team} {format} International?",
    "What is the highest individual score in a Women's {format} International match by any player?",
    "Show me the result of the {tournament} semi-final between {team} and {team}.",
    "Tell me about the player with the most sixes in a single {tournament} season.",
    "Which team won the last {tournament} and who was the captain?",
    "Give me details of the tied {format} match between {team} and {team} in 1986.",
    "What was the margin of victory for {team} in the last {format} match against {team}?",
    "Who was the leading wicket-taker in the last {tournament}?",
    "Show me the final scorecard of the historic tied {format} match between {team} and {team} in 1986.",
    "Tell me about the highest partnership for the opening wicket in {format}s in Sharjah.",
    "What is the most wickets taken by a {player} in a single season of the {tournament}?",
    "Give me information about the Women's {format} International series between {team} and {team} in 2021.",
    "Who won the last edition of the {tournament}?",
    "What is the highest total ever chased down in a {format} International match?",
    "Show me the result of the {team} vs. {team} match in the {tournament} semi-final.",
    "Tell me about the centuries scored by {player} in {format} matches at the {venue}.",
    "What is the highest run partnership for the third wicket in {format} Internationals?",
    "Give me details of the first-ever {format} match played between {team} and {team} in 1877.",
    "Who won the last {team} vs. {team} {format} series, and what was the margin?",
    "What is the highest team score in a {format} International match at the {venue}?",
    "Show me the result of the {tournament} final between {team} and {team}.",
    "Tell me about the most recent tied {format} match in cricket history and the teams involved.",
    "Who is the captain of the {team}n cricket team for the upcoming {format} series against {team}?",
    "What is the highest individual score by a {team}i player in a {tournament} match?",
    "Give me information about the {format} match series between {team} and {team} in 2020-21.",
    "Who was the Man of the Series in the last season of the {tournament}?",
    "What is the highest run chase in the history of the {tournament}?",
    "Show me the result of the last {format} International match between {team} and {team}.",
    "Tell me about the debut {format} match of {player} and his performance in it.",
    "What is the most runs scored by a player in a single edition of the {tournament}?",
    "Who won the last {format} match between {team} and {team}, and where was it played?",
    "Give me details of the tied {format} between {team} and {team} in 1999.",
    "What is the highest partnership for the fourth wicket in {format} matches at the {venue}?",
    "Show me the result of the {tournament} final between {team} and {team}.",
    "Tell me about the highest individual score by a West {team}n player in a Women's {format} International match.",
    "Who is the current captain of the {team} cricket team for {format} matches?",
    "What is the highest run partnership for the fifth wicket in {tournament} matches?",
    "Give me information about the {tournament} semi-final between {team} and {team}.",
    "What is the margin of victory for {team} in the last {tournament} final?",
    "Show me the final scorecard of the tied {format} match between {team} and {team} in 1986.",
    "Tell me about the leading run-scorer in the last edition of the {tournament}.",
    "What is the highest team total in a {format} match at the {venue}?",
    "Who won the last {format} International series between {team} and {team}?",
    "Give me details of the {tournament} final between {team} and {team}.",
    "What is the highest run partnership for the sixth wicket in {format}s?",
    "Show me the result of the last {tournament} match between {team} and {team}.",
    "Tell me about the player with the most five-wicket hauls in {format} matches at the {venue}.",
    "Who was the Man of the Match in the last {team} vs. {team} {format} match?",
    "What is the highest individual score in a {tournament} final?",
    "Give me information about the Men's {format} International series between {team} and {team} in 2022.",
    "What is the margin of victory for {team} in the last {tournament}?",
    "Show me the most recent {format} match between {team} and {team} and its result.",
    "Tell me about the highest partnership for the seventh wicket in {format} matches at {venue}.",
    "Who won the last edition of the {tournament}?",
    "What is the highest team total in a {format} match at the {venue}?",
    "Give me details of the tied {format} International between {team} and {team} in 2020.",
    "What is the highest run partnership for the eighth wicket in {format} Internationals?",
    "Show me the result of the {tournament} final between {team} and {team}.",
    "Tell me about the centuries scored by {player} in {format} matches at the {venue}.",
    "What is the highest individual score by a {team} player in a Women's {format} International match?",
    "Who is the captain of the {team} cricket team for the upcoming {format} series against {team}?",
    "What is the highest run partnership for the ninth wicket in {format}s at the {venue}?",
    "Give me information about the {format} match series between {team} and {team} in 2020.",
    "Who won the last {team} vs. {team} {format} International series, and what was the score?",
    "What is the highest team score in a {format} International match at {venue}?",
    "Show me the result of the {tournament} final between {team} and {team}.",
    "Tell me about the most recent tied {format} match in cricket history and the teams involved.",
    "Who is the captain of the {team}n cricket team for the upcoming {format} series against {team}?",
    "What is the highest individual score by an {team} player in a {tournament} match?",
    "Give me details of the {format} series between {team} and {team} in 2021.",
    "What is the margin of victory for {team} in the last {tournament} final?",
    "Show me the final scorecard of the tied {format} match between {team} and {team} in 2011.",
    "Tell me about the leading wicket-taker in the last edition of the {tournament}.",
    "What is the highest run partnership for the tenth wicket in {format} matches at the {venue}?",
    "Who won the last Women's {format} International series between {team} and {team}?",
    "Give me information about the {tournament} between {team} and {team}.",
    "What is the highest total ever chased down in a Women's {format} International match?",
    "Show me the result of the last {tournament} match between {team} and {team}.",
    "Tell me about the debut {format} match of {player} and his performance in it.",
    "What is the most runs scored by an {team}n player in a single edition of the {tournament}?",
    "Who won the last {format} series between {team} and {team}, and what was the score?",
    "What is the highest team score in a {format} match at the {venue}?",
    "Give me details of the tied {format} match between {team} and {team} in 1939.",
    "What is the margin of victory for {team} in the last {tournament} final?",
    "Show me the most recent {format} match between {team} and {team} and its result."
]

# %%
player_dismissals_questions = [
    "Tell me about the most catches taken by {player} in {format} matches.",
    "Who holds the record for the most run-outs in {format}s, and against which teams were they achieved?",
    "Give me information about the highest number of stumpings by {player} in {format} Internationals.",
    "What is the career dismissal rate of {player} in {format} cricket?",
    "Who has the record for the most catches by a fielder in {format} leagues, and which team do they play for?",
    "Tell me about the most run-outs by {player} in {format}s.",
    "What is the highest number of stumpings by {player} in {format} matches?",
    "Give me details about the most catches taken by {player} in {format} Internationals.",
    "Who holds the record for the most dismissals by a wicketkeeper in a single {format} match, and against which team was it achieved?",
    "Tell me about the most run-outs by {player} in {format} leagues.",
    "What is the career dismissal rate of {player} in {format}s?",
    "Give me information about the highest number of stumpings by {player} in {format}s.",
    "Who has the record for the most catches by a fielder in a {format} league season, and in which season was it achieved?",
    "Tell me about the most dismissals by {player} in {format} matches.",
    "What is the highest number of stumpings by {player} in {format} leagues?",
    "Give me details about the most catches taken by {player} in {format}s.",
    "Who holds the record for the most run-outs in a {format} league match, and against which team was it achieved?",
    "Tell me about the most stumpings by {player} in {format} Internationals.",
    "What is the career dismissal rate of {player} in {format}s?",
    "Give me information about the highest number of catches by {player} in {format} matches.",
    "Who has the record for the most dismissals by a wicketkeeper in a single {format} series, and against which team was it achieved?",
    "Tell me about the most catches taken by {player} in {format} leagues.",
    "What is the highest number of stumpings by {player} in {format} matches?",
    "Give me details about the most run-outs by {player} in {format}s.",
    "Who holds the record for the most catches by a fielder in {format} Internationals?",
    "Tell me about the most dismissals by {player} in {format} leagues.",
    "What is the career dismissal rate of {player} in {format} matches?",
    "Give me information about the highest number of stumpings by {player} in {format} leagues.",
    "Who has the record for the most run-outs in a {format} league season, and in which season was it achieved?",
    "Tell me about the most stumpings by {player} in {format} matches.",
    "What is the highest number of catches by {player} in {format} Internationals?",
    "Give me details about the most dismissals by {player} in {format} matches.",
    "Who holds the record for the most dismissals by a wicketkeeper in {format}s, and against which teams were they achieved?",
    "Tell me about the most catches taken by {player} in {format} leagues.",
    "What is the career dismissal rate of {player} in {format}s?",
    "Give me information about the highest number of stumpings by {player} in {format} leagues.",
    "Who has the record for the most run-outs by {player} in {format} leagues?",
    "Tell me about the most stumpings by {player} in {format}s.",
    "What is the highest number of catches by {player} in {format} matches?",
    "Give me details about the most dismissals by {player} in {format} leagues.",
    "Who holds the record for the most dismissals by a fielder in a single {format} match, and against which team was it achieved?",
    "Tell me about the most run-outs by {player} in {format} matches.",
    "What is the career dismissal rate of {player} in {format} Internationals?",
    "Give me information about the highest number of stumpings by {player} in {format}s.",
    "Who has the record for the most dismissals by a wicketkeeper in a {format} league match, and against which team was it achieved?",
    "Tell me about the most catches taken by {player} in {format} matches.",
    "What is the highest number of stumpings by {player} in {format} leagues?",
    "Give me details about the most run-outs by {player} in {format}s.",
    "Who holds the record for the most dismissals by {player} in {format} matches.",
    "Tell me about the most stumpings by {player} in {format} Internationals.",
    "What is the career dismissal rate of {player} in {format}s?",
    "Give me information about the highest number of catches by {player} in {format} matches.",
    "Who has the record for the most run-outs in a {format} league season, and in which season was it achieved?",
    "Tell me about the most dismissals by {player} in {format} leagues.",
    "What is the highest number of stumpings by {player} in {format} matches?",
    "Give me details about the most catches taken by {player} in {format} leagues.",
    "Who holds the record for the most dismissals by a fielder in a single {format} series, and against which team was it achieved?",
]

# %%
player_player_vs_player_battles_questions = [
    "Compare the career batting averages of {player} and {player} in {format} matches.",
    "Who has a better strike rate in {format}s, {player} or {player}?",
    "Give me the head-to-head statistics of {player} and {player} in {format} matches.",
    "What is the highest partnership for the second wicket between {player} and {player} in {format}?",
    "Compare the number of centuries scored by {player} and {player} in {format} cricket.",
    "Who has more 5-wicket hauls in {format}, {player} or {player}?",
    "Show me the career runs scored by {player} and {player} in {format} matches.",
    "What is the average score of {player} against {player} in {format}s?",
    "Give me the head-to-head records of {player} and {player} in {format} matches.",
    "Compare the strike rates of {player} and {player} in {format}s.",
    "Who has taken more wickets in {format}, {player} or {player}?",
    "Show me the career boundaries hit by {player} and {player} in {format} cricket.",
    "What is the highest individual score by {player} against {player} in {format} matches?",
    "Compare the number of catches taken by {player} and {player} in {format}.",
    "Who has more wickets in {format}, {player} or {player}?",
    "Give me the head-to-head statistics of {player} and {player} in {format} matches.",
    "What is the average partnership between {player} and {player} in {format}s?",
    "Compare the career bowling averages of {player} and {player} in {format} matches.",
    "Who has more sixes in {format}, {player} or {player}?",
    "Show me the runs scored by {player} and {player} in {format} matches.",
    "What is the highest individual score by {player} against {player} in {format}s?",
    "Give me the head-to-head records of {player} and {player} in {format} matches.",
    "Compare the number of catches taken by {player} and {player} in {format}.",
    "Who has a better economy rate in {format}s, {player} or {player}?",
    "Show me the career wickets taken by {player} and {player} in {format} cricket.",
    "What is the average partnership between {player} and {player} in {format}?",
    "Give me the head-to-head statistics of {player} and {player} in {format}.",
    "Compare the number of runs scored by {player} and {player} in {format}.",
    "Who has more centuries in {format}s, {player} or {player}?",
    "Show me the career strike rates of {player} and {player} in {format}.",
    "What is the highest individual score by {player} against {player} in {format} matches?",
    "Give me the head-to-head records of {player} and {player} in {format}s.",
    "Compare the career wickets taken by {player} and {player} in {format} matches.",
    "Who has more catches in {format} cricket, {player} or {player}?",
    "Show me the number of centuries scored by {player} and {player} in {format}.",
    "What is the average score of {player} against {player} in {format} matches?",
    "Give me the head-to-head statistics of {player} and {player} in {format} matches.",
    "Compare the number of sixes hit by {player} and {player} in {format}.",
    "Who has a better economy rate in {format}s, {player} or {player}?",
    "Show me the career batting averages of {player} and {player} in {format} matches.",
    "What is the highest partnership for the third wicket between {player} and {player} in {format}s?",
    "Give me the head-to-head records of {player} and {player} in {format}.",
    "Compare the number of wickets taken by {player} and {player} in {format} matches.",
    "Who has more catches in {format}, {player} or {player}?",
    "Show me the runs scored by {player} and {player} in {format} matches.",
    "What is the average partnership between {player} and {player} in {format}?",
    "Give me the head-to-head statistics of {player} and {player} in {format}s.",
    "Compare the number of centuries scored by {player} and {player} in {format}.",
    "Who has a better strike rate in {format}, {player} or {player}?",
    "Show me the career boundaries hit by {player} and {player} in {format}.",
    "What is the highest individual score by {player} against {player} in {format} matches?",
    "Give me the head-to-head records of {player} and {player} in {format} matches.",
    "Compare the number of wickets taken by {player} and {player} in {format}.",
    "Who has more sixes in {format} matches, {player} or {player}?",
    "Show me the career bowling averages of {player} and {player} in {format}.",
    "What is the highest partnership for the fourth wicket between {player} and {player} in {format}s?",
    "Give me the head-to-head statistics of {player} and {player} in {format} matches.",
    "Compare the number of catches taken by {player} and {player} in {format}.",
    "Who has more centuries in {format}, {player} or {player}?",
    "Show me the career wickets taken by {player} and {player} in {format}.",
    "What is the average partnership between {player} and {player} in {format} matches?",
    "Give me the head-to-head records of {player} and {player} in {format}s.",
    "Compare the number of runs scored by {player} and {player} in {format} matches.",
    "Who has a better economy rate in {format}s, {player} or {player}?",
    "Show me the highest individual score by {player} against {player} in {format}.",
    "What is the career batting average of {player} in {format} matches?",
    "Give me the head-to-head statistics of {player} and {player} in {format} matches.",
    "Compare the number of wickets taken by {player} and {player} in {format}.",
    "Who has more catches in {format}, {player} or {player}?",
    "Show me the career boundaries hit by {player} and {player} in {format}.",
    "What is the highest partnership for the fifth wicket between {player} and {player} in {format} matches.",
    "Give me the head-to-head records of {player} and {player} in {format}s.",
    "Compare the number of centuries scored by {player} and {player} in {format} matches.",
    "Who has a better strike rate in {format}s, {player} or {player}?",
    "Show me the career runs scored by {player} and {player} in {format}.",
    "What is the highest individual score by {player} against {player} in {format} matches.",
    "Give me the head-to-head statistics of {player} and {player} in {format} matches.",
    "Compare the career bowling averages of {player} and {player} in {format}.",
    "Who has more sixes in {format}, {player} or {player}?",
    "Show me the career batting averages of {player} and {player} in {format}s.",
    "What is the highest partnership for the sixth wicket between {player} and {player} in {format}.",
    "Give me the head-to-head records of {player} and {player} in {format} matches.",
]

# %%
player_player_records_and_milestones_questions = [
    "What is the highest individual score by {player} in {format} matches?",
    "Tell me about the most runs scored by {player} in {format}.",
    "Who holds the record for the fas{format} century in {format}s, and in which match did they achieve it?",
    "What is the career batting average of {player} in {format}?",
    "Give me details about the highest partnership for the opening wicket between {player} and {player} in {format}.",
    "Who has the most sixes in {format} matches, {player} or {player}?",
    "Tell me about the most wickets taken by {player} in {format} cricket.",
    "What is the record for the most catches by a fielder in {format}, and who holds it?",
    "Give me information about the fas{format} fifty in {format}, including the player and the number of balls faced.",
    "Who is the leading run-scorer in {format}s, and how many runs have they scored?",
    "Tell me about the highest individual score by {player} in {format} matches.",
    "What is the career strike rate of {player} in {format}?",
    "Give me details about the most wickets taken by {player} in {format}.",
    "Who has the record for the highest number of boundaries in a single {format} match, and in which match was it achieved?",
    "Tell me about the most centuries scored by {player} in {format} cricket.",
    "What is the career bowling average of {player} in {format} matches?",
    "Give me information about the highest partnership for the fourth wicket between {player} and {player} in {format}.",
    "Who holds the record for the most sixes in a single {format} match, and against which team was it achieved?",
    "Tell me about the fas{format} century in {format}, including the player and the number of balls faced.",
    "What is the highest individual score by {player} in {format}?",
    "Give me details about the most wickets taken by {player} in {format} cricket.",
    "Who has the record for the highest number of catches in a {format} series, and against which team was it achieved?",
    "Tell me about the most runs scored by {player} in {format}s.",
    "What is the career batting average of {player} in {format} matches?",
    "Give me information about the highest partnership for the fifth wicket between {player} and {player} in {format}.",
    "Who holds the record for the most sixes in an {format} series, and against which team was it achieved?",
    "Tell me about the fas{format} fifty in {format}, including the player and the number of balls faced.",
    "What is the highest individual score by {player} in {format} matches?",
    "Give me details about the most wickets taken by {player} in {format}.",
    "Who has the record for the most boundaries in a single {format} season, and in which season was it achieved?",
    "Tell me about the most centuries scored by {player} in {format}.",
    "What is the career strike rate of {player} in {format}s?",
    "Give me information about the highest partnership for the sixth wicket between {player} and {player} in {format} matches.",
    "Who holds the record for the most sixes in a single {format} series, and against which team was it achieved?",
    "Tell me about the most runs scored by {player} in {format} matches.",
    "What is the highest individual score by {player} in {format}?",
    "Give me details about the most wickets taken by {player} in {format} cricket.",
    "Who has the record for the most catches in a {format}, and which team do they play for?",
    "Tell me about the most wickets taken by {player} in {format}.",
    "What is the career bowling average of {player} in {format} matches?",
    "Give me information about the highest partnership for the seventh wicket between {player} and {player} in {format}.",
    "Who holds the record for the most sixes in a single {format} match, and against which team was it achieved?",
    "Tell me about the fas{format} century in {format} matches, including the player and the number of balls faced.",
    "What is the highest individual score by {player} in {format}?",
    "Give me details about the most runs scored by {player} in {format} matches.",
    "Who has the record for the most boundaries in a single {format} match, and against which team was it achieved?",
    "Tell me about the most centuries scored by {player} in {format} matches.",
    "What is the career strike rate of {player} in {format}s?",
    "Give me information about the highest partnership for the eighth wicket between {player} and {player} in {format}.",
    "Who holds the record for the most catches in a single {format} season, and for which team was it achieved?",
    "Tell me about the most runs scored by {player} in {format}.",
    "What is the highest individual score by {player} in {format}?",
    "Give me details about the most wickets taken by {player} in {format} cricket.",
    "Who has the record for the most sixes in an {format} match, and against which team was it achieved?",
    "Tell me about the most centuries scored by {player} in {format}.",
    "What is the career bowling average of {player} in {format}?",
    "Give me information about the highest partnership for the ninth wicket between {player} and {player} in {format} matches.",
    "Who holds the record for the most catches in a single {format} match, and against which team was it achieved?",
    "Tell me about the most wickets taken by {player} in {format}.",
    "What is the highest individual score by {player} in {format}?",
    "Give me details about the most boundaries hit by {player} in {format}.",
    "Who has the record for the most boundaries in a single {format} season, and in which league was it achieved?",
    "Tell me about the most runs scored by {player} in {format} matches.",
    "What is the career batting average of {player} in {format}s?",
    "Give me information about the highest partnership for the tenth wicket between {player} and {player} in {format}.",
    "Who holds the record for the most sixes in a single {format} match, and against which team was it achieved?",
    "Tell me about the most centuries scored by {player} in {format}.",
    "What is the highest individual score by {player} in {format}s?",
    "Give me details about the most wickets taken by {player} in {format}.",
    "Who has the record for the most boundaries in a single {format} match, and against which team was it achieved?",
    "Tell me about the most runs scored by {player} in {format}.",
    "What is the career strike rate of {player} in {format}?",
    "Give me information about the highest partnership for the opening wicket between {player} and {player} in {format}.",
    "Who holds the record for the most sixes in a single {format} match, and against which team was it achieved?",
    "Tell me about the fas{format} century in {format} leagues, including the player and the number of balls faced.",
    "What is the highest individual score by {player} in {format}s?",
    "Give me details about the most wickets taken by {player} in {format} cricket.",
    "Who has the record for the most catches by a wicketkeeper in {format}?",
    "Tell me about the most centuries scored by {player} in {format}s.",
    "What is the career batting average of {player} in {format} matches?",
    "Give me information about the highest partnership for the second wicket between {player} and {player} in {format}.",
    "Who holds the record for the most sixes in {format}, and in which league was it achieved?",
    "Tell me about the fas{format} fifty in {format} matches, including the player and the number of balls faced.",
    "What is the highest individual score by {player} in {format}?",
    "Give me details about the most wickets taken by {player} in {format} cricket.",
    "Who has the record for the most boundaries in a single {format} match, and against which team was it achieved?",
    "Tell me about the most runs scored by {player} in {format}.",
    "What is the career strike rate of {player} in {format}?",
    "Give me information about the highest partnership for the third wicket between {player} and {player} in {format}s.",
    "Who holds the record for the most sixes in a single {format} series, and against which team was it achieved?",
]

# %% [markdown]
# ### Tournament

# %%
tournament_overview_questions = [
    "Tell me about the history of the {tournament}, including its inaugural edition.",
    "Who were the standout players in the {tournament} final between {team} and {team}?",
    "Give me an overview of the {tournament} and its most successful team.",
    "What records were set during the {tournament}, and by which players?",
    "Tell me about the origins and format of the {tournament} in {team}.",
    "Who has the most centuries in {tournament} history, and how many?",
    "Give me an overview of the {tournament} and its past champions.",
    "What are the key milestones of the {tournament}, and who holds batting records?",
    "Tell me about the emergence of the {tournament} and its impact on West {team} cricket.",
    "Who are the top run-scorers and wicket-takers in the {tournament} tournament's history?",
    "Give me an overview of the {tournament} and its marquee players.",
    "What are the unique features of the {tournament}, and which players have excelled in it?",
    "Tell me about the evolution of the T10 League in the {team} and its star performers.",
    "Who holds the record for the most sixes in a single edition of the {tournament}?",
    "Give me an overview of the {tournament} and its historical significance in {team} cricket.",
    "What is the history of the {tournament}, and who are the leading run-scorers?",
    "Tell me about the growth of the {tournament} in {team} and notable moments in its history.",
    "Who are the top run-scorers and wicket-takers in the Women's {tournament} tournament's history?",
    "Give me an overview of the {tournament} in {team} and its star players.",
    "What records were set during the {tournament}, and by which players?",
    "Tell me about the significance of the {tournament} in {team} cricket.",
    "Who holds the record for the highest team total in a single season of the {tournament}?",
    "Give me an overview of the {tournament} and its impact on North American cricket.",
    "What is the history of the {tournament} and its marquee overseas players?",
    "Tell me about the emergence of the {tournament} and the European teams involved.",
    "Who are the leading run-scorers and wicket-takers in the {tournament}?",
    "Give me an overview of the Women's {tournament} and its significance in women's cricket.",
    "What records were set during the {tournament}, and by which players?",
    "Tell me about the impact of the {tournament} on {team} cricket and international stars.",
    "Who holds the record for the fas{format} century in the {tournament}?",
    "Give me an overview of the {tournament} in the {team} and its ambitions.",
    "What is the history of the {tournament} and its marquee overseas players?",
    "Tell me about the emergence of the {tournament} in {team} and its unique rules.",
    "Who are the leading run-scorers and wicket-takers in the {tournament} history?",
    "Give me an overview of the {tournament} in {team} and its impact on {team} cricket.",
    "What records were set during the {tournament}, and by which players?",
    "Tell me about the inaugural edition of the {tournament} and its top performers.",
    "Who holds the record for the most wickets in a single edition of the {tournament}?",
]

# %%
tournament_records_questions = [
    "Tell me about the highest run-scorer in the history of the {tournament} and their total runs.",
    "Who holds the record for the most centuries in a single edition of the {tournament}, and in which year did this happen?",
    "Give me details about the highest team total in the history of the {tournament} and in which match did it occur?",
    "What is the record for the most wickets in a single edition of the {tournament}, and who achieved it?",
    "Tell me about the most sixes hit in a single season of the {tournament} and the player who accomplished it.",
    "Who holds the record for the highest individual score in {tournament} history, and in which match did it occur?",
    "Give me information about the most runs scored in a single season of the {tournament} and the player with the record.",
    "What records were set during the {tournament} 2016, and which players achieved these milestones?",
    "Tell me about the highest partnership for any wicket in the history of the {tournament}, and who were the batting pair?",
    "Who holds the record for the most wickets in {tournament} history, and how many wickets did they take?",
    "Give me details about the highest run-scorer in the history of the {tournament} and their total runs.",
    "What is the record for the fas{format} century in {tournament} history, and which player achieved it?",
    "Tell me about the most sixes hit in the history of the T10 League, and the player who holds this record.",
    "Who holds the record for the most catches in a single season of the {tournament} and the number of catches taken?",
    "Give me information about the highest team total in the history of the {tournament} and in which season it was achieved.",
    "What records were set during the {tournament}, and which players achieved these milestones?",
    "Tell me about the highest run-scorer in the history of the {tournament} and their total runs.",
    "Who holds the record for the most wickets in Women's {tournament} history, and how many wickets did they take?",
    "Give me details about the highest run-scorer in the history of the {tournament} and their total runs.",
    "What is the record for the most sixes hit in a single season of the {tournament}, and which player achieved it?",
    "Tell me about the highest team total in the {tournament} history and the match in which it was achieved.",
    "Who holds the record for the most wickets in a single edition of the {tournament} and the number of wickets taken?",
    "Give me information about the highest run-scorer in the history of the {tournament} and their total runs.",
    "What records were set during the {tournament}, and which players achieved these milestones?",
    "Tell me about the highest run-scorer in the {tournament} and their total runs.",
    "Who holds the record for the most wickets in the Women's {tournament} history, and how many wickets did they take?",
    "Give me details about the highest team total in the history of the {tournament} and in which season it was achieved.",
    "What is the record for the most sixes hit in a single season of the {tournament}, and which player achieved it?",
    "Tell me about the highest run-scorer in the history of the {tournament} and their total runs.",
    "Who holds the record for the most wickets in a single season of the {tournament} and the number of wickets taken?",
    "Give me information about the highest run-scorer in the history of the {tournament} and their total runs.",
    "What records were set during the Women's {tournament}, and which players achieved these milestones?",
    "Tell me about the highest run-scorer in the history of the {tournament} ({team}) and their total runs.",
    "Who holds the record for the most wickets in a single season of the {tournament}, and the number of wickets taken?",
    "Give me details about the highest team total in the history of the {tournament} and in which season it was achieved.",
    "What is the record for the most sixes hit in a single season of the {tournament}, and which player achieved it?",
]

# %%
tournament_batting_analysis_questions = [
    "Can you provide a detailed batting analysis of {player}'s performance in the 2003 {tournament}?",
    "Tell me about {player}'s batting statistics in the 2016 {tournament}, including runs scored and strike rate.",
    "Give me insights into {player}'s performance with the bat in the 2020 {tournament}, including centuries and fifties.",
    "What were the key highlights of {player}'s batting in the {tournament} 2013, and his contribution to the team?",
    "Provide a detailed batting analysis of {player}'s record-breaking season in the {tournament} in 2015/16.",
    "Tell me about {player}'s batting performance in the {tournament} 2017, including her role in {team}'s victory.",
    "Give me insights into {player}'s batting statistics in the {tournament} 2019, such as runs scored and boundaries hit.",
    "What records were set by {player} during his phenomenal season in the {tournament} 2016?",
    "Provide a detailed analysis of {player}'s batting in the {tournament} 2020, including her strike rate and high scores.",
    "Tell me about the batting prowess of {player} in the {tournament} 2018, and his impact on his team's success.",
    "Give me insights into {player}'s batting statistics in the 2018 {tournament}, including centuries and partnerships.",
    "What were the key moments of {player}'s match-winning century in the {tournament} final in 2019?",
    "Provide a detailed analysis of {player}'s batting in the {tournament} 2019, including her consistency and role in her team's success.",
    "Tell me about the batting performance of {player} in the {tournament}, and his contribution to his team's journey.",
    "Give me insights into {player}'s batting statistics in the {tournament}, such as her strike rate and boundaries hit.",
    "What records were set by Shai Hope during his remarkable season in the {tournament} 2020?",
    "Provide a detailed batting analysis of {player}'s performance in the {tournament} 2018, including her runs and player of the match awards.",
    "Tell me about the consistency of {player}'s batting in the {tournament} 2017 and his contribution to the {team}.",
    "Give me insights into {player}'s batting statistics in the Women's {tournament}, such as her highest score and boundaries hit.",
    "What were the key highlights of {player}'s batting performance in the {tournament} in 2019?",
    "Provide a detailed analysis of {player}'s batting in the {tournament} 2020, including her strike rate and impact.",
    "Tell me about the batting prowess of {player} in the {tournament} 2019 and his role as a match-winner.",
    "Give me insights into {player}'s batting statistics in the {tournament} 2016, including his runs scored and strike rate.",
    "What records were set by {player} during her outstanding season in the Women's {tournament} 2020/21?",
    "Provide a detailed batting analysis of {player}'s performance in the {tournament} 2021, including his centuries and consistency.",
    "Tell me about the batting performance of {player} in the {tournament} 2016 and his role in the {team}.",
    "Give me insights into {player}'s batting statistics in the {tournament}, such as her highest score and boundaries hit.",
    "What were the key moments of {player} exceptional century in the {tournament} 2017?",
    "Provide a detailed analysis of {player}'s batting in the {tournament} 2018/19, including her all-round contributions.",
]

# %%
tournament_bowling_analysis_questions = [
    "Can you provide a detailed bowling analysis of {player}'s performance in the 1992 {tournament}?",
    "Tell me about {player}'s bowling statistics in the 2016 {tournament}, including wickets taken and economy rate.",
    "Give me insights into {player}'s performance with the ball in the 2020 {tournament}, including his wicket haul and economy rate.",
    "What were the key highlights of {player}'s bowling in the {tournament} 2009, and his contribution to the team?",
    "Provide a detailed bowling analysis of {player}'s record-breaking season in the {tournament} in 2011.",
    "Tell me about {player}'s bowling performance in the {tournament} 2017, including her role in {team}'s success.",
    "Give me insights into {player}'s bowling statistics in the {tournament} 2020, such as wickets taken and maidens bowled.",
    "What records were set by {player} during his phenomenal season in the {tournament} 2012?",
    "Provide a detailed analysis of {player}'s bowling in the {tournament} 2020, including her wicket haul and economy rate.",
    "Tell me about the impact of {player}'s bowling in the {tournament} 2019/20 and his role in {team}.",
    "Give me insights into {player}'s bowling statistics in the ICC {tournament} 2018, such as wickets taken and dot balls bowled.",
    "What were the key moments of {player}'s match-winning spell in the {tournament} 2015 final?",
    "Provide a detailed analysis of {player}'s bowling in the {tournament} 2020/21, including her wicket haul and economy rate.",
    "Tell me about the bowling performance of {player} in the {tournament}, and his impact on his team's journey.",
    "Give me insights into {player}'s bowling statistics in the Women's {format} Challenge 2021, such as her wickets and economy rate.",
    "What records were set by {player} during his outstanding season in the {tournament} 2020?",
    "Provide a detailed bowling analysis of {player}'s performance in the {tournament} 2021.",
    "Tell me about {player}'s bowling statistics in the {tournament} 2021, including wickets taken and dot balls bowled.",
    "Give me insights into {player}'s bowling in the {tournament} 2019/20, including her wicket haul.",
    "What were the key moments of {player}'s impactful spell in the {tournament} 2019?",
    "Provide a detailed analysis of {player}'s bowling in the {tournament}, including her wicket haul and economy rate.",
    "Tell me about the bowling prowess of {player} in the {tournament} 1999 and his role in {team}'s journey.",
    "Give me insights into {player}'s bowling statistics in the Women's {tournament}.",
    "What records were set by {player} during his phenomenal season in the {tournament} 2014?",
    "Provide a detailed bowling analysis of {player}'s performance in the {tournament} 2021, including his pace and bouncers.",
    "Tell me about {player}'s bowling statistics in the {tournament} 2020.",
    "Give me insights into {player}'s performance with the ball in the {tournament} 2016/17, including his wicket haul and economy rate.",
    "What were the key moments of {player}'s impressive spell in the {tournament} 2021?",
    "Provide a detailed analysis of {player}'s bowling in the {tournament} 2020/21, including her wicket haul and control over swing.",
]

# %% [markdown]
# ### Ground

# %%
ground_match_history_questions = [
    "Tell me about the historical match at {venue} featuring {team} and {team} in 1971.",
    "What is the highest team total at the {venue}, and in which match did it occur?",
    "Give me details about the iconic {format} match between {team} and the {venue} at the {venue} in 1960.",
    "Who was the highest run-scorer at {venue} during the 2001 {team} vs. {team} {format} match?",
    "Tell me about the famous tied {format} between {team} and {team} at {venue} in 2003.",
    "What is the lowest team total at the Oval, and in which match did it happen?",
    "Give me information about the historic match where {team} won their first {format} series at the {venue}.",
    "Who was the standout {player} in the historic {format} match between {team} and {team} at {venue} in 1952?",
    "Tell me about the thrilling match at {venue} Stadium where {team} chased a record target against {team}.",
    "What is the highest run chase at {venue}, and in which match did it occur?",
    "Give me details about the memorable {format} match at {venue} featuring {team} and {venue} in 2016.",
    "Who holds the record for the most centuries at the {venue}, and what are their career achievements?",
    "Tell me about the classic {format} encounter at {venue} between {team} and {team} in 2019.",
    "What is the lowest team total at {venue}, and in which match did it happen?",
    "Give me information about the iconic match at {venue}, where {team} won the {tournament}.",
    "Who was the captain of the {venue} during their historic win at {venue} in the 1966 {format} series?",
    "Tell me about the thrilling {format} match between {team} and {team} at {venue} in 2002.",
    "What is the highest individual score at the {venue}, and in which match did it occur?",
    "Give me details about the famous tied {format} between {team} and {team} at the {venue} in 1986.",
    "Who scored the fas{format} century at the {venue} Stadium, and in which format did it happen?",
    "Tell me about the historic match at the Oval where {team} secured their {tournament} victory in 2005.",
    "What is the lowest team total at the {venue}, and in which match did it happen?",
    "Give me information about the memorable match at {venue}, where {team} chased down a target against {team}.",
    "Who was the standout {player} in the historic {format} series between {team} and the {venue} at {venue} in 1976?",
    "Tell me about the iconic {format} match at the {venue} featuring {team} and {team} in 2008.",
    "What is the highest team total at the {venue}, and in which match did it occur?",
    "Give me details about the classic {format} encounter at {venue} Stadium between {team} and {team} in 2018.",
    "Who holds the record for the most centuries at {venue}, and what are their career achievements?",
    "Tell me about the thrilling {format} match at {venue} between {team} and {team} in 2019.",
    "What is the lowest team total at {venue}, and in which match did it happen?",
    "Give me information about the historic match at {venue}, where {team} defeated {team} in a thrilling {format}.",
    "Who was the captain of {team} during the memorable victory at the {venue} in the 1977 {format} series?",
    "Tell me about the famous tied {format} match between {team} and the {venue} at {venue} in 2015.",
    "What is the highest individual score at the {venue} Stadium, and in which format did it happen?",
    "Give me details about the iconic {format} match at {venue} where {team} achieved a dramatic victory against {team} in 1981.",
    "Who scored the fas{format} century at {venue}, and in which match did it happen?",
    "Tell me about the historic match at the {venue} featuring {team} and {team} in 1877, the first-ever {format} match.",
    "What is the lowest team total at {venue}, and in which match did it happen?",
    "Give me information about the memorable {format} match at the {venue} between {team} and {team} in 2011.",
    "Who was the captain of {team} during their historic win at {venue} in the 2008 {format} series?",
]

# %%
ground_batting_analysis_questions = [
    "Tell me about the highest individual score at {venue}, and who was the {player}?",
    "Who has the highest batting average at the {venue}, and who is the {player}?",
    "Give me details about the most centuries at the {venue}, and who is the {player} with the record?",
    "What is the highest partnership for any wicket at {venue}, and who were the batsmen?",
    "Tell me about the best strike rate at {venue}, and who was the {player} achieving it?",
    "Who holds the record for the most boundaries at the Oval, and who is the {player}?",
    "Give me information about the highest run-scorer at {venue}, and their total runs.",
    "What is the highest run chase at {venue}, and in which match did it happen?",
    "Tell me about the best boundary-hitter at {venue}, and who is the {player} with the record?",
    "Who has the highest sixes count at {venue}, and who is the {player} with the record?",
    "Give me details about the most centuries at {venue}, and who is the {player}?",
    "What is the highest individual score at {venue}, and who was the {player}?",
    "Tell me about the best batting average at {venue}, and who is the {player} with the highest average?",
    "Who holds the record for the most boundaries at {venue}, and who is the {player}?",
    "Give me information about the highest run-scorer at {venue}, and their total runs.",
    "fWhat is the highest run chase at the {venue}, and in which match did it happen?",
    "Tell me about the best strike rate at {venue}, and who was the {player} achieving it?",
    "Who has the highest sixes count at the {venue}, and who is the {player} with the record?",
    "Give me details about the most centuries at {venue}, and who is the {player}?",
    "What is the highest individual score at the {venue}, and who was the {player}?",
    "Tell me about the best batting average at the {venue}, and who is the {player} with the highest average?",
    "Who holds the record for the most boundaries at {venue}, and who is the {player}?",
    "Give me information about the highest run-scorer at {venue}, and their total runs.",
    "What is the highest run chase at the Oval, and in which match did it happen?",
    "Tell me about the best strike rate at {venue}, and who was the {player} achieving it?",
    "Who has the highest sixes count at {venue}, and who is the {player} with the record?",
    "Give me details about the most centuries at {venue} Stadium, and who is the {player}?",
    "What is the highest individual score at {venue}, and who was the {player}?",
    "Tell me about the best batting average at {venue}, and who is the {player} with the highest average?",
    "Who holds the record for the most boundaries at {venue}, and who is the {player}?",
    "Give me information about the highest run-scorer at {venue}, and their total runs.",
    "What is the highest run chase at {venue}, and in which match did it happen?",
    "Tell me about the best strike rate at {venue}, and who was the {player} achieving it?",
    "Who has the highest sixes count at {venue}, and who is the {player} with the record?",
    "Give me details about the most centuries at {venue}, and who is the {player}?",
    "What is the highest individual score at the {venue}, and who was the {player}?",
    "Tell me about the best batting average at {venue}, and who is the {player} with the highest average?",
    "Who holds the record for the most boundaries at the {venue}, and who is the {player}?",
]

# %%
ground_bowling_analysis_questions = [
    "Tell me about the best bowling figures at {venue}, and who was the {player}?",
    "Who has the lowest bowling average at the {venue}, and who is the {player}?",
    "Give me details about the most five-wicket hauls at the {venue}, and who is the {player} with the record?",
    "What is the best bowling partnership for any wicket at {venue}, and who were the {player}s?",
    "Tell me about the best economy rate at {venue}, and who was the {player} achieving it?",
    "Who holds the record for the most maidens at the Oval, and who is the {player}?",
    "Give me information about the most wickets at {venue}, and their total wickets.",
    "What is the lowest team total defended at {venue}, and in which match did it happen?",
    "Tell me about the best dot ball count at {venue} Stadium, and who is the {player} with the record?",
    "Who has the most four-wicket hauls at {venue}, and who is the {player} with the record?",
    "Give me details about the most five-wicket hauls at {venue}, and who is the {player}?",
    "What is the best bowling figures at {venue}, and who was the {player}?",
    "Tell me about the lowest economy rate at {venue}, and who was the {player} achieving it?",
    "Who holds the record for the most maidens at {venue}, and who is the {player}?",
    "Give me information about the most wickets at {venue}, and their total wickets.",
    "What is the lowest team total defended at the {venue}, and in which match did it happen?",
    "Tell me about the best dot ball count at {venue}, and who is the {player} with the record?",
    "Who has the most four-wicket hauls at the {venue}, and who is the {player} with the record?",
    "Give me details about the most five-wicket hauls at {venue}, and who is the {player}?",
    "What is the best bowling figures at the {venue}, and who was the {player}?",
    "Tell me about the lowest economy rate at the {venue}, and who was the {player} achieving it?",
    "Who holds the record for the most maidens at {venue}, and who is the {player}?",
    "Give me information about the most wickets at {venue}, and their total wickets.",
    "What is the lowest team total defended at the Oval, and in which match did it happen?",
    "Tell me about the best dot ball count at {venue}, and who is the {player} with the record?",
    "Who has the most four-wicket hauls at {venue}, and who is the {player} with the record?",
    "Give me details about the most five-wicket hauls at {venue} Stadium, and who is the {player}?",
    "What is the best bowling figures at {venue}, and who was the {player}?",
    "Tell me about the lowest economy rate at {venue}, and who was the {player} achieving it?",
    "Who holds the record for the most maidens at {venue}, and who is the {player}?",
    "Give me information about the most wickets at {venue}, and their total wickets.",
    "What is the lowest team total defended at {venue}, and in which match did it happen?",
    "Tell me about the best dot ball count at {venue}, and who is the {player} with the record?",
    "Who has the most four-wicket hauls at {venue}, and who is the {player} with the record?",
    "Give me details about the most five-wicket hauls at the {venue}, and who is the {player}?",
]

# %% [markdown]
# ### Team

# %%
team_performance_questions = [
    "Tell me about {team}'s highest team total in a {format} match, and who were the top scorers?",
    "What is the lowest team total for {team} in {format}s, and who were the opposition {player}s?",
    "Give me information about {team}'s most significant victory margin in {format} Internationals.",
    "Who holds the record for the most wickets taken in a single {format} match for {team}, and in which match did it happen?",
    "Tell me about {team}'s best run chase in {format}s, and who played a crucial role in that match?",
    "What is the highest number of boundaries hit by {team} in a {format} league match, and against which team was it achieved?",
    "Give me details about {team}'s biggest defeat in {format} matches, including the opposition team and margin of loss.",
    "Who has the highest individual score for the {venue} in a {format} International, and against which team was it scored?",
    "Tell me about {team}'s most significant partnership for the second wicket in {format} matches.",
    "What is the lowest team total for {team} in {format} leagues, and who were the opposition {player}s responsible?",
    "Give me information about {team}'s best powerplay score in {format} Internationals.",
    "Who holds the record for the most sixes in a single {format} innings for {team}, and against which team was it achieved?",
    "Tell me about {team}'s highest run chase in {format} matches, and who were the top run-scorers in that match?",
    "What is the highest partnership for the third wicket for {team} in {format}s?",
    "Give me details about {team}'s lowest team total in a {format} league match, including the opposition team and {player}s responsible.",
    "Who has the highest individual score for {team} in {format} matches, and in which match did they achieve it?",
    "Tell me about {team}'s most significant victory margin in {format} leagues, including the opposition team.",
    "What is the lowest team total for the {venue} in {format} Internationals, and who were the opposition {player}s?",
    "Give me information about {team}'s highest team total in {format}s, and who played crucial innings in that match?",
    "Who holds the record for the most wickets taken in a single {format} International match for {team}, and against which team was it achieved?",
    "Tell me about {team}'s best run chase in {format} matches, and who played a vital role in that match?",
    "What is the highest partnership for the fourth wicket for {team} in {format} leagues?",
    "Give me details about {team}'s lowest team total in a {format} International, including the opposition team and {player}s responsible.",
    "Who has the highest individual score for {team} in {format}s, and in which match did they achieve it?",
    "Tell me about {team}'s most significant victory margin in {format} matches, including the opposition team and margin of victory.",
    "What is the lowest team total for {team} in {format} leagues, and who were the opposition {player}s responsible?",
    "Give me information about {team}'s best powerplay score in {format} Internationals.",
    "Who holds the record for the most sixes in a single {format} innings for {team}, and against which team was it achieved?",
    "Tell me about {team}'s highest run chase in {format} matches, and who were the top run-scorers in that match?",
    "What is the highest partnership for the fifth wicket for {team} in {format} leagues?",
    "Give me details about the {venue}' lowest team total in a {format} International, including the opposition team and {player}s responsible.",
    "Who has the highest individual score for {team} in {format} matches, and in which match did they achieve it?",
    "Tell me about {team}'s most significant victory margin in {format} leagues, including the opposition team.",
    "What is the lowest team total for {team} in {format}s, and who were the opposition {player}s responsible?",
    "Give me information about {team}'s highest team total in {format} Internationals, and who were the top scorers?",
    "Who holds the record for the most wickets taken in a single {format} match for {team}, and in which match did it happen?",
    "Tell me about {team}'s best run chase in {format}s, and who played a crucial role in that match?",
    "What is the highest number of boundaries hit by {team} in a {format} league match, and against which team was it achieved?",
    "Give me details about {team}'s lowest team total in {format} matches, including the opposition team and margin of defeat.",
    "Who has the highest individual score for {team} in {format} leagues, and against which team was it scored?",
    "Tell me about {team}'s most significant partnership for the second wicket in {format} Internationals.",
    "What is the lowest team total for {team} in {format} leagues, and who were the opposition {player}s responsible?",
    "Give me information about {team}'s best powerplay score in {format}s.",
    "Who holds the record for the most sixes in a single {format} innings for the {venue}, and against which team was it achieved?",
    "Tell me about {team}'s highest team total in {format} leagues, and who were the top scorers?",
    "What is the highest partnership for the third wicket for {team} in {format} matches?",
    "Give me details about {team}'s lowest team total in a {format} league match, including the opposition team and {player}s responsible.",
    "Who has the highest individual score for {team} in {format} Internationals, and in which match did they achieve it?",
    "Tell me about the most significant victory margin for {team} in {format} matches, including the opposition team and margin of victory.",
    "What is the lowest team total for {team} in {format} Internationals, and who were the opposition {player}s responsible?",
    "Give me information about {team}'s highest run chase in {format} leagues, and who were the top run-scorers in that match?",
    "Who holds the record for the most wickets taken in a single {format} league match for {team}, and against which team was it achieved?",
    "Tell me about {team}'s best run chase in {format} International matches, and who played a crucial role in that match?",
    "What is the highest partnership for the fourth wicket for the {venue} in {format} matches?",
    "Give me details about {team}'s lowest team total in {format} Internationals, including the opposition team and {player}s responsible.",
    "Who has the highest individual score for {team} in {format} leagues, and in which match did they achieve it?",
    "Tell me about the most significant victory margin for {team} in {format}s, including the opposition team and margin of victory.",
    "What is the lowest team total for {team} in {format} leagues, and who were the opposition {player}s responsible?",
    "Give me information about {team}'s highest team total in {format} leagues, and who were the top scorers?",
    "Who holds the record for the most wickets taken in a single {format} match for {team}, and in which match did it happen?",
    "Tell me about {team}'s best run chase in {format} International matches, and who played a vital role in that match?",
    "What is the highest number of boundaries hit by {team} in {format}s, and against which team was it achieved?",
    "Give me details about {team}'s lowest team total in {format} league matches, including the opposition team and {player}s responsible.",
    "Who has the highest individual score for {team} in {format} Internationals, and in which match did they achieve it?",
]

# %%
team_partnerships_questions = [
    "Tell me about the highest opening partnership for {team} in {format} matches, and who were the openers?",
    "What is the highest run partnership for {team} for the third wicket in {format}s?",
    "Give me information about {team}'s best partnership for the fourth wicket in {format} Internationals.",
    "Who holds the record for the highest partnership for the fifth wicket in {format} matches for {team}?",
    "Tell me about {team}'s highest partnership for the sixth wicket in {format}s.",
    "What is the highest run partnership for {team} for the seventh wicket in {format} leagues?",
    "Give me details about {team}'s most significant partnership for the eighth wicket in {format} Internationals.",
    "Who has the record for the highest run partnership for the ninth wicket in {format} matches for the {venue}?",
    "Tell me about {team}'s best partnership for the tenth wicket in {format}s.",
    "What is the highest run partnership for {team} for any wicket in {format} Internationals?",
    "Give me information about {team}'s highest opening partnership in {format} leagues, and who were the openers?",
    "Who holds the record for the highest run partnership for the second wicket in {format}s for {team}?",
    "Tell me about the highest partnership for {team} for the third wicket in {format} matches.",
    "What is the highest run partnership for {team} for the fourth wicket in {format} Internationals?",
    "Give me details about {team}'s best partnership for the fifth wicket in {format}s.",
    "Who has the record for the highest partnership for the sixth wicket in {format} leagues for {team}?",
    "Tell me about the highest run partnership for the seventh wicket in {format} matches for {team}.",
    "What is the highest partnership for {team} for the eighth wicket in {format} Internationals?",
    "Give me information about the highest run partnership for the ninth wicket in {format}s for {team}.",
    "Who holds the record for the best partnership for the tenth wicket in {format} Internationals for the {venue}?",
    "Tell me about {team}'s highest opening partnership in {format} matches, and who were the openers?",
    "What is the highest run partnership for {team} for the second wicket in {format} leagues?",
    "Give me details about {team}'s highest partnership for the third wicket in {format}s.",
    "Who has the record for the highest run partnership for the fourth wicket in {format} matches for {team}?",
    "Tell me about the best partnership for the fifth wicket in {format} Internationals for {team}.",
    "What is the highest run partnership for {team} for the sixth wicket in {format}s?",
    "Give me information about the highest partnership for the seventh wicket in {format} leagues for {team}.",
    "Who holds the record for the highest run partnership for the eighth wicket in {format} matches for {team}?",
    "Tell me about {team}'s best partnership for the ninth wicket in {format} Internationals.",
    "What is the highest run partnership for the tenth wicket in {format}s for {team}?",
    "Give me details about the highest partnership for {team} for any wicket in {format} matches.",
    "Who has the record for the highest run partnership for the second wicket in {format} leagues for {team}?",
    "Tell me about {team}'s highest opening partnership in {format} Internationals, and who were the openers?",
    "What is the highest run partnership for {team} for the third wicket in {format}s?",
    "Give me information about the best partnership for {team} for the fourth wicket in {format} leagues.",
    "Who holds the record for the highest partnership for the fifth wicket in {format} matches for {team}?",
    "Tell me about the highest run partnership for the sixth wicket in {format} leagues for {team}.",
    "What is the highest partnership for {team} for the seventh wicket in {format}s?",
    "Give me details about {team}'s best partnership for the eighth wicket in {format} matches.",
    "Who has the record for the highest run partnership for the ninth wicket in {format} Internationals for the {venue}?",
    "Tell me about {team}'s highest partnership for the tenth wicket in {format} leagues.",
    "What is the highest run partnership for {team} for any wicket in {format} matches?",
    "Give me information about the highest partnership for the second wicket in {format}s for {team}.",
    "Who holds the record for the highest run partnership for the third wicket in {format} Internationals for {team}?",
    "Tell me about the best partnership for the fourth wicket in {format} leagues for {team}.",
    "What is the highest run partnership for the fifth wicket in {format} matches for {team}?",
    "Give me details about {team}'s highest partnership for the sixth wicket in {format} leagues.",
    "Who has the record for the highest run partnership for the seventh wicket in {format}s for {team}?",
    "Tell me about the highest partnership for the eighth wicket in {format} matches for {team}.",
    "What is the highest run partnership for the ninth wicket in {format} Internationals for {team}?",
    "Give me information about {team}'s best partnership for the tenth wicket in {format} leagues.",
    "Who holds the record for the highest run partnership for {team} for the second wicket in {format} Internationals?",
    "Tell me about the highest partnership for the third wicket in {format}s for the {venue}.",
    "What is the highest run partnership for {team} for the fourth wicket in {format} leagues?",
    "Give me details about {team}'s highest partnership for the fifth wicket in {format} matches.",
    "Who has the record for the highest run partnership for the sixth wicket in {format} Internationals for {team}?",
    "Tell me about the best partnership for the seventh wicket in {format} leagues for {team}.",
    "What is the highest run partnership for the eighth wicket in {format}s for {team}?",
    "Give me information about {team}'s highest partnership for the ninth wicket in {format} matches.",
    "Who holds the record for the highest run partnership for the tenth wicket in {format} Internationals for {team}?",
    "Tell me about the highest partnership for {team} for any wicket in {format} matches.",
    "What is the highest run partnership for {team} for the second wicket in {format} leagues?",
    "Give me details about {team}'s highest partnership for the third wicket in {format}s.",
    "Who has the record for the highest partnership for the fourth wicket in {format} leagues for {team}?",
    "Tell me about the highest run partnership for the fifth wicket in {format} matches for {team}.",
    "What is the highest partnership for {team} for the sixth wicket in {format} Internationals?",
    "Give me information about the best partnership for the seventh wicket in {format} leagues for the {venue}.",
    "Who holds the record for the highest run partnership for the eighth wicket in {format}s for {team}?",
    "Tell me about {team}'s highest partnership for the ninth wicket in {format} matches.",
    "What is the highest run partnership for the tenth wicket in {format} Internationals for {team}?",
    "Give me details about the highest partnership for {team} for any wicket in {format} leagues.",
    "Who has the record for the highest run partnership for the second wicket in {format} matches for {team}?",
]

# %%
team_bowling_analysis_questions = [
    "Tell me about the best bowling figures in an {format} match for {team}, and who was the {player}?",
    "What is the most wickets taken by a {player} in a {format} series for {team}?",
    "Give me details about {team}'s best economy rate in {format} Internationals, and who was the {player}?",
    "Who holds the record for the most maidens in a {format} league match for {team}?",
    "Tell me about {team}'s most wickets in a single {format} match, and who was the {player}?",
    "What is the lowest economy rate in {format}s for {team}, and who was the {player}?",
    "Give me information about {team}'s best bowling performance in a {format} league match, and who was the {player}?",
    "Who has the best strike rate in {format} matches for {team}, and who is the {player}?",
    "Tell me about {team}'s highest wicket-taker in {format} Internationals, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a {format} league season for {team}?",
    "Give me details about the lowest economy rate in {format} matches for the {venue}, and who was the {player}?",
    "Who holds the record for the best bowling figures in a {format} International match for {team}?",
    "Tell me about {team}'s highest wicket-taker in {format}s, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a single {format} match for {team}?",
    "Give me information about {team}'s best economy rate in {format} leagues, and who was the {player}?",
    "Who has the best strike rate in {format}s for {team}, and who is the {player}?",
    "Tell me about {team}'s most wickets in a {format} league season, and who was the {player}?",
    "What is the lowest economy rate in {format} matches for {team}, and who was the {player}?",
    "Give me details about the best bowling figures in an {format} match for {team}, and who was the {player}?",
    "Who holds the record for the most maidens in a {format} International match for {team}?",
    "Tell me about {team}'s highest wicket-taker in {format} leagues, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a {format} league season for the {venue}?",
    "Give me information about {team}'s best bowling performance in a {format} match, and who was the {player}?",
    "Who has the best strike rate in {format} Internationals for {team}, and who is the {player}?",
    "Tell me about {team}'s highest wicket-taker in {format} matches, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a single {format} International match for {team}?",
    "Give me details about {team}'s best economy rate in {format}s, and who was the {player}?",
    "Who holds the record for the most wickets in a {format} league season for {team}?",
    "Tell me about {team}'s highest wicket-taker in {format} Internationals, and how many wickets have they taken?",
    "What is the lowest economy rate in {format} matches for {team}, and who was the {player}?",
    "Give me information about {team}'s best bowling performance in an {format} match, and who was the {player}?",
    "Who has the best strike rate in a {format} league match for the {venue}, and who is the {player}?",
    "Tell me about {team}'s most wickets in a {format} league season, and who was the {player}?",
    "What is the most wickets taken by a {player} in a {format} International series for {team}?",
    "Give me details about {team}'s best economy rate in {format} matches, and who was the {player}?",
    "Who holds the record for the most maidens in an {format} match for {team}?",
    "Tell me about {team}'s highest wicket-taker in {format} leagues, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a single {format} league match for {team}?",
    "Give me information about {team}'s best bowling performance in a {format} match, and who was the {player}?",
    "Who has the best strike rate in {format} Internationals for {team}, and who is the {player}?",
    "Tell me about {team}'s most wickets in a {format} league season, and who was the {player}?",
    "What is the lowest economy rate in {format} International matches for {team}, and who was the {player}?",
    "Give me details about {team}'s best bowling figures in an {format} match, and who was the {player}?",
    "Who holds the record for the most maidens in a {format} match for the {venue}?",
    "Tell me about the highest wicket-taker in {format} matches for {team}, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a single {format} International match for {team}?",
    "Give me information about {team}'s best economy rate in {format} leagues, and who was the {player}?",
    "Who has the best strike rate in {format} matches for {team}, and who is the {player}?",
    "Tell me about {team}'s most wickets in a {format} league season, and who was the {player}?",
    "What is the most wickets taken by a {player} in a {format} International series for the {venue}?",
    "Give me details about {team}'s best bowling performance in a {format} match, and who was the {player}?",
    "Who holds the record for the most maidens in a {format} league match for {team}?",
    "Tell me about {team}'s highest wicket-taker in {format} Internationals, and how many wickets have they taken?",
    "What is the lowest economy rate in {format} matches for {team}, and who was the {player}?",
    "Give me information about the best bowling figures in a {format} league match for {team}, and who was the {player}?",
    "Who has the best strike rate in an {format} match for {team}, and who is the {player}?",
    "Tell me about {team}'s most wickets in an {format} match, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a {format} league season for {team}?",
    "Give me details about {team}'s best economy rate in {format} Internationals, and who was the {player}?",
    "Who holds the record for the most maidens in a {format} series for {team}?",
    "Tell me about {team}'s highest wicket-taker in {format} leagues, and how many wickets have they taken?",
    "What is the most wickets taken by a {player} in a {format} International match for {team}?",
    "Give me information about {team}'s best bowling performance in an {format} match, and who was the {player}?",
]

# %%
team_batting_analysis_questions = [
    "Tell me about the highest individual score in an {format} match for {team}, and who was the {player}?",
    "What is the most runs scored by a {player} in a {format} series for {team}?",
    "Give me details about {team}'s best strike rate in {format} Internationals, and who was the {player}?",
    "Who holds the record for the most centuries in a {format} league for {team}?",
    "Tell me about {team}'s highest run-scorer in a single {format} match, and how many runs did they score?",
    "What is the highest batting average in {format}s for {team}, and who is the {player}?",
    "Give me information about {team}'s best boundary-hitter in {format} leagues, and who was the {player}?",
    "Who has the highest sixes count in {format} matches for {team}, and who is the {player}?",
    "Tell me about {team}'s most runs in {format} Internationals, and how many runs have they scored?",
    "What is the most runs scored by a {player} in a {format} league season for {team}?",
    "Give me details about the best strike rate in {format} matches for the {venue}, and who was the {player}?",
    "Who holds the record for the highest partnership for any wicket in an {format} match for {team}?",
    "Tell me about {team}'s highest run-scorer in {format}s, and how many runs did they score?",
    "What is the highest individual score in a single {format} match for {team}, and who was the {player}?",
    "Give me information about {team}'s best batting average in {format} leagues, and who is the {player}?",
    "Who has the highest boundary count in {format} Internationals for {team}, and who is the {player}?",
    "Tell me about the most centuries in a {format} series for {team}, and who is the {player}?",
    "What is the most runs scored by a {player} in a single {format} International match for {team}?",
    "Give me details about the best strike rate in an {format} match for the {venue}, and who was the {player}?",
    "Who holds the record for the highest partnership for any wicket in a {format} league match for {team}?",
    "Tell me about {team}'s best boundary-hitter in {format} Internationals, and who was the {player}?",
    "What is the highest batting average in {format} matches for {team}, and who is the {player}?",
    "Give me information about {team}'s most runs in {format} leagues, and how many runs have they scored?",
    "Who has the highest sixes count in {format} International matches for {team}, and who is the {player}?",
    "Tell me about {team}'s highest run-scorer in {format} matches, and how many runs did they score?",
    "What is the most runs scored by a {player} in a {format} league season for {team}?",
    "Give me details about the highest individual score in an {format} match for the {venue}, and who was the {player}?",
    "Who holds the record for the most centuries in a {format} league for {team}?",
    "Tell me about {team}'s best strike rate in {format} Internationals, and who was the {player}?",
    "What is the highest partnership for any wicket in a {format} league match for {team}?",
    "Give me information about {team}'s best boundary-hitter in {format} leagues, and who is the {player}?",
    "Who has the highest boundary count in {format} matches for {team}, and who is the {player}?",
    "Tell me about {team}'s most centuries in {format} Internationals, and who is the {player}?",
    "What is the most runs scored by a {player} in a single {format} International match for {team}?",
    "Give me details about the best batting average in an {format} match for {team}, and who was the {player}?",
    "Who holds the record for the highest partnership for any wicket in {format} matches for {team}?",
    "Tell me about {team}'s highest run-scorer in {format} leagues, and how many runs did they score?",
    "What is the highest individual score in {format} Internationals for the {venue}, and who was the {player}?",
    "Give me information about the most centuries in {format} matches for {team}, and who is the {player}?",
    "Who has the highest sixes count in {format} league matches for {team}, and who is the {player}?",
    "Tell me about {team}'s best strike rate in {format} Internationals, and who was the {player}?",
    "What is the highest batting average in {format}s for {team}, and who is the {player}?",
    "Give me details about the highest partnership for any wicket in a {format} league match for {team}?",
    "Who holds the record for the most runs scored by a {player} in an {format} match for {team}?",
    "Tell me about {team}'s best boundary-hitter in {format} leagues, and who was the {player}?",
    "What is the most runs scored by a {player} in a single {format} match for {team}?",
    "Give me information about {team}'s most centuries in {format} Internationals, and who is the {player}?",
    "Who has the highest boundary count in {format} International matches for {team}, and who is the {player}?",
    "Tell me about {team}'s highest run-scorer in {format} matches, and how many runs did they score?",
    "What is the highest individual score in a {format} league season for the {venue}, and who was the {player}?",
    "Give me details about the best batting average in {format} matches for {team}, and who is the {player}?",
    "Who holds the record for the highest partnership for any wicket in an {format} match for {team}?",
    "Tell me about {team}'s best strike rate in {format} Internationals, and who was the {player}?",
    "What is the highest run-scorer in {format} league matches for {team}, and how many runs have they scored?",
    "Give me information about {team}'s best boundary-hitter in {format} Internationals, and who was the {player}?",
    "Who has the highest sixes count in {format}s for {team}, and who is the {player}?",
    "Tell me about the most runs scored by a {player} in a {format} International match for {team}?",
    "What is the best batting average in a single {format} match for {team}, and who was the {player}?",
]

# %% [markdown]
# ###Questions

# %%
player_list = [player_batting_performance_questions, player_bowling_performance_questions, player_match_context_questions,
               player_player_vs_player_battles_questions, player_player_records_and_milestones_questions,
               player_dismissals_questions]

# %%
team_list = [team_performance_questions, team_partnerships_questions,
             team_batting_analysis_questions,team_bowling_analysis_questions]

# %%
ground_list = [ground_match_history_questions,
               ground_batting_analysis_questions,ground_bowling_analysis_questions]

# %%
tour_list = [tournament_overview_questions,
             tournament_records_questions,
             tournament_batting_analysis_questions,
             tournament_bowling_analysis_questions]

# %%
final_list = [player_list, team_list, ground_list, tour_list]

# %%
count = 0

for i in final_list:
    for j in i:
      for k in j:
        count += 1

print(count)
# Out:
# 995

# %%
tq_full.to_csv("unique_elements.csv", index=False)

# %%
tq_full = pd.read_csv("unique_elements.csv")

# %%
names_df = pd.read_csv("./grayball_v0.1/query_handling/final_name_df.csv")

# %%
venue_wiki = pd.read_csv("./grayball_v0.1/query_handling/venue_wiki.csv")

# %%
names_df.columns
# Out:
# Index(['players', 'nation', 'name', 'full_names', 'r1', 'r2'], dtype='object')

# %%
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer
import transformers
import torch

from huggingface_hub import login
access_token_read = "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"
login(token = access_token_read)

model = "mistralai/Mistral-7B-Instruct-v0.2"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu.

# %%
B_INST, E_INST = "[INST]","[/INST]"
B_SYS, E_SYS = "<s>", "</s>"

prompt = """Act as a cricket expert. You have to help create structured json from the query asked by the user.
Please extract key information elements from the query and represent them as a JSON object matching the schema provided below.

{
  "gender": "default would be male if not mentioned in query else can be [male,female]",
  "department": "pick one or more from ['bat', 'ball', 'field', 'all'] give output in list",
  "historic_event": "If asked about historic event then yes else no",
  "players_involved": "can be one of [single, partnership, head_to_head, multiple] based on how many players will have to be checked",
  "player_name": "If single or head_to_head or partnership in players_involved then mention player name else all",
  "second_player": "If head_to_head or partnership in players_involved then mention second player name else all",
  "teams_involved": "can be one of [single, partnership, head_to_head, multiple] based on the query",
  "team_name": "If single or head_to_head in teams_involved then mention team name else all",
  "second_team": "If head_to_head or partnership in teams_involved then mention opponent team name else all",
  "format": "If type of the match mentioned can be [Test, ODI, T20] else all",
  "powerplay_type" : "If powerplay type is specified in the query then pick one of [batting, bowling, mandatory] else all",
  "powerplay_number" : "If powerplay number is specified in the query then pick one of [1, 2, 3] else all",
  "innings": "If innings is specified in the query then pick one of [first,second] else default is all",
  "overs_start": "If over number specified in the query then mention overs start for it else default is all",
  "overs_end": "If over number specified in the query then mention overs end for it else default is all",
  "recent_type": "If asked about performance in last few matches then yes else no",
  "history": "If asked about performance longer than recent past then yes else no",
  "recent_number": "if recent_type is yes then number of matches required else all",
  "tournament": "Name of a specific tournament to consider else all",
  "venue": "Name of a specific venue/ground to consider else all",
  "second_venue": "Name of a second venue for comparison else all",
  "batter_number": "If batting position is specified in the query then mention it in a list like [1] or [5,6] else default is all",
  "bowler_number": "If bowler position is specified in the query then mention it in a list like [1] or [5,6] else default is all",
  "fielding": "If fielding stats are required then yes else no",
  "city": "Name of the host city to consider else all",
  "home_team" : "Name of the home team to consider else all",
  "away_team" : "Name of the away team to consider else all",
  "match_result": "Match result filter criteria [won, lost, draw] else all",
  "margin_runs_start": "Filter by matches won or lost by a specific run margin start else all",
  "margin_runs_end": "Filter by matches won or lost by a specific run margin end else all",
  "margin_wickets_start": "Filter by matches won or lost by a specific wicket margin start else all",
  "margin_wickets_end": "Filter by matches won or lost by a specific wicket margin end else all",
  "date_start": "Date start asked in the query or all",
  "date_end": "Date end asked in the query or all",
  "toss_result": "Team that won or lost the toss if it is mentioned else all",
  "toss_decision": "Made to bat or bowl according to the toss result else all",
  "top_k": "will be integer if query type is list type then number of top k players to return else all",
  "best_or_worst": "if top_k if present then it should be sorted by best or worst else all",
}
Only mention one of powerplay_type or powerplay_number.
Just focus of the statistics that should be extracted to answer the query.
Only add information present in the query don't add the answer.
Focus completely on the instructions given in the json.
Ensure all the keys of json are returned according to the instructions.
Even if you know the answer don't mention it in the json.
Every key should be filled according to the instructions.
Note:- If asked about the best player then multiple players will have to be checked and top_k would be 1
and others keys will be filled accordingly.
Chasing means second innings.
Overs numbers will be mentioned like from 20 to 30. For eg:- How many runs were scored till over 30
so overs_start will be 20 and overs_end will be 30.
If asked about recent form or there is need for recent form then change
recent_type to yes and recent_number to 5
Ensure the syntax of the output is correct.
Opening batsmen are [1,2], Middle order batsmen are [3,4,5], lower middle order batsmen are [6,7,8], lower order batsmen are [9,10,11]
Opening bowler means bowler_number [1,2]
In T20, death over means overs_start : 15 and overs_end : 20.
In T20, middle overs means overs_start : 6 and overs_end : 15.
In T20, start overs or powerplay means overs_start : 0 and overs_end : 6.
In ODI, death over means overs_start : 40 and overs_end : 50.
In ODI, middle overs means overs_start : 20 and overs_end : 30.
In ODI, start overs or powerplay means overs_start : 0 and overs_end : 20.
In Test, there is no over limitations
till over 30 over means overs_start : 0 and overs_end : 30.
Innings and format should be all until mentioned otherwise.
won or lost by or less than 50 runs means margin_runs_start : 0 and margin_runs_end : 50.
won or lost by more than 50 runs means margin_runs_start : 50 and margin_runs_end : inf.
won or lost by or less than 4 wickets means margin_wickets_start : 0 and margin_wickets_end : 4.
won or lost by more than 4 wickets means margin_wickets_start : 4 and margin_wickets_end : 10.

for example:-
Input:- "how has Australian performed in death overs?"
Output:- {
  "gender": "male",
  "department": "all",
  "historic_event": "no",
  "players_involved": "multiple",
  "player_name": "all",
  "team_involved": "single",
  "team_name": "Australia",
  "format": ["T20"],
  "overs_start": 15,
  "overs_end": 20
}

Input:- "who are top 5 bowler for India in T20 since 2018?"
Output:- {
  "gender": "male",
  "department": ["ball"],
  "historic_event": "no",
  "players_involved": "multiple",
  "player_name": "all",
  "team_name": "India",
  "format": ["T20"],
  "recent_type": "no",
  "history": "yes",
  "date_start": "2018",
  "best_k": 5,
  "best_or_worst": "best"
}

Input:- "how has India opening batsmen performed recently?"
Output:- {
  "gender": "male",
  "department": ['bat'],
  "historic_event": "no",
  "players_involved": "multiple",
  "player_name": "all",
  "teams_involved": "single",
  "team_name": "India",
  "batter_number": [1,2],
  "recent_type": "yes",
  "recent_number": 5
}
"""

# %%
import itertools

num_questions = 7000000

players = names_df.loc[747:, "name"]
match_types = tq_full["match_type"].unique()
teams = tq_full["team"].unique()
venues = tq_full["venue"].unique()
tournaments = tq_full["event_name"].unique()

variables = [players, match_types, teams, venues, tournaments]
combinations = itertools.product(*variables)

questions = []
count = 0
for i in final_list:
    for j in i:
      for k in j:
        for c in combinations:
            if count >= num_questions:
                break

            count += 1

print(f"{count} questions generated")
# Out:
# 7000000 questions generated

# %%
c[0]
# Out:
# 'Subhasis Samal'

# %%
import random
import os
count = 747
new_list = []
for idx, row in names_df[747:].iterrows():
  player = row["name"]
  for r in list(tq_full["match_type"].unique()):
    format = r
    for t in list(tq_full["team"].unique()):
      team = t
      for v in list(tq_full["venue"].unique()):
        venue = v
        for g in list(tq_full["event_name"].unique()):
          tournament = g
          for i in final_list:
              for j in i:
                for k in j:
                  k = k.replace("{player}", player)
                  k = k.replace("{team}", team)
                  k = k.replace("{tournament}", tournament)
                  k = k.replace("{venue}", venue)
                  k = k.replace("{format}", format)
                  text = f"{B_INST}{B_SYS}{prompt}{E_SYS} {k}{E_INST}".strip()
                  fg = pipeline(text, max_length=8000)
                  pred = fg[0]["generated_text"].split("[/INST]")[1].lstrip().rstrip()
                  if os.path.exists("questions.csv"):
                    new_df = pd.read_csv('questions.csv')
                    new_df.loc[len(new_df.index)] = {"count": count, "question": k, "answer": pred}
                    new_df.to_csv("questions.csv", index=False)
                    count += 1
                  else:
                    new_list.append({"count": count, "question": k, "answer": pred})
                    new_df = pd.DataFrame(new_list)
                    new_df.to_csv("questions.csv", index=False)
                    count += 1
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-33-4c59545269bd> in <cell line: 5>()
#      22                   k = k.replace("{format}", format)
#      23                   text = f"{B_INST}{B_SYS}{prompt}{E_SYS} {k}{E_INST}".strip()
# ---> 24                   fg = pipeline(text, max_length=8000)
#      25                   pred = fg[0]["generated_text"].split("[/INST]")[1].lstrip().rstrip()
#      26                   if os.path.exists("questions.csv"):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     206               ids of the generated text.
#     207         """
# --> 208         return super().__call__(text_inputs, **kwargs)
#     209
#     210     def preprocess(
#
# ...

# %%
new_df
# Out:
#      count                                           question
# 0        0  What are the career batting statistics of SC C...
# 1        1  Tell me about SC Cook's total runs scored in T...
# 2        1  How many centuries has SC Cook scored in Test ...
# 3        1  Give me the details of SC Cook's highest Test ...
# 4        1  What is the strike rate of SC Cook in Test mat...
# ..     ...                                                ...
# 724      1  What is the most wickets taken by a SC Cook in...
# 725      1  Give me information about South Africa's best ...
# 726      1  Who has the best strike rate in Test Internati...
# 727      1  Tell me about South Africa's most wickets in a...
# 728      1  What is the lowest economy rate in Test Intern...
#
# [729 rows x 2 columns]

# %%
# import os
# os.remove("questions.csv")

# %%
# import pandas as pd
# df = pd.read_csv("questions.csv")
# len(df)
# Out:
# 654

# %%
# df
# Out:
#      count                                           question  \
# 0        0  What are the career batting statistics of Aish...
# 1        1  Tell me about Aisha Mohamed's total runs score...
# 2        2  How many centuries has Aisha Mohamed scored in...
# 3        3  Give me the details of Aisha Mohamed's highest...
# 4        4  What is the strike rate of Aisha Mohamed in Te...
# ..     ...                                                ...
# 649    649  Tell me about South Africa's best boundary-hit...
# 650    650  What is the highest batting average in Test ma...
# 651    651  Give me information about South Africa's most ...
# 652    652  Who has the highest sixes count in Test Intern...
# 653    653  Tell me about South Africa's highest run-score...
#
#                                                 answer
# 0    {\n  "gender": "female",\n  "department": ["ba...
# 1    {\n  "gender": "female",\n  "department": "all...
# ...
